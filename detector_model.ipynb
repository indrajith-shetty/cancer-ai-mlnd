# %%
def main():
    from keras.preprocessing.image import ImageDataGenerator
    from my_model import MyModel
    
    batch_size = 100
    input_h=150

    # this is the augmentation configuration we will use for training
    train_datagen = ImageDataGenerator(
        rescale=1. / 255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

    # this is a generator that will read pictures found in
    #  of 'data/train', and indefinitely generate
    # batches of augmented image data
    train_generator = train_datagen.flow_from_directory(
        '../data/train',  # this is the target directory
        target_size=(input_h, input_h),  # all images will be resized to 150x150
        batch_size=batch_size,
        class_mode='categorical')




    val_datagen = ImageDataGenerator(rescale=1. / 255)
    # this is a similar generator, for validation data
    validation_generator = val_datagen.flow_from_directory(
        '../data/valid',
        target_size=(input_h, input_h),
        batch_size=batch_size,
        class_mode='categorical')


    
    model = MyModel().get_model(input_h)
    try:
        model.load_weights('first_try.h5')
    except:
        print('could not load the existing weights. proceeding..')
    from keras.callbacks import ModelCheckpoint
    checkpointer = ModelCheckpoint(filepath='first_try.h5', verbose=1, save_best_only=True)
    model.fit_generator(
        train_generator,
        steps_per_epoch=2000 // batch_size,
        epochs=5,
        validation_data=validation_generator,
        validation_steps=150 // batch_size,
        callbacks=[checkpointer])

    #model.save_weights('first_try.h5')

# %%
if __name__ == '__main__':
    main()
# Out:
# Found 2000 images belonging to 3 classes.
# Found 150 images belonging to 3 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 150, 150, 30)      2280
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 75, 75, 30)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 75, 75, 40)        30040
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 18, 18, 40)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 18, 18, 60)        21660
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 9, 9, 60)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 4860)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 60)                291660
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 60)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 3)                 183
# _________________________________________________________________
# activation_5 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 345,823
# Trainable params: 345,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 19/20 [===========================>..] - ETA: 15s - loss: 0.7939 - acc: 0.6816
# Epoch 00001: val_loss improved from inf to 1.13641, saving model to first_try.h5
# 20/20 [==============================] - 318s 16s/step - loss: 0.7849 - acc: 0.6860 - val_loss: 1.1364 - val_acc: 0.4700
# Epoch 2/5
# 19/20 [===========================>..] - ETA: 18s - loss: 0.7861 - acc: 0.6821
# Epoch 00002: val_loss improved from 1.13641 to 0.80717, saving model to first_try.h5
# 20/20 [==============================] - 362s 18s/step - loss: 0.7836 - acc: 0.6845 - val_loss: 0.8072 - val_acc: 0.6200
# Epoch 3/5
# 19/20 [===========================>..] - ETA: 16s - loss: 0.7697 - acc: 0.6868
# Epoch 00003: val_loss did not improve
# 20/20 [==============================] - 330s 16s/step - loss: 0.7702 - acc: 0.6855 - val_loss: 0.9500 - val_acc: 0.5100
# Epoch 4/5
# 19/20 [===========================>..] - ETA: 16s - loss: 0.7638 - acc: 0.6863
# Epoch 00004: val_loss did not improve
# 20/20 [==============================] - 334s 17s/step - loss: 0.7615 - acc: 0.6855 - val_loss: 0.9903 - val_acc: 0.5400
# Epoch 5/5
# 19/20 [===========================>..] - ETA: 16s - loss: 0.7844 - acc: 0.6837
# Epoch 00005: val_loss did not improve
# 20/20 [==============================] - 334s 17s/step - loss: 0.7807 - acc: 0.6850 - val_loss: 0.9745 - val_acc: 0.5000
